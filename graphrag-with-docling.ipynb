# %% [markdown]
# # Graph RAG Implementation with LlamaIndex
#
# This notebook demonstrates the implementation of **Graph RAG (Retrieval-Augmented Generation)** using LlamaIndex. Graph RAG combines knowledge graphs with large language models to provide more accurate and context-aware answers by understanding entity relationships and community structures.
#
# ## Overview
# 1. **Data Loading**: Load news articles dataset
# 2. **LLM Setup**: Configure OpenRouter with GPT-4o-mini
# 3. **Graph Extractor**: Custom implementation to extract entities and relationships
# 4. **Graph Store**: Neo4j-based store with community detection
# 5. **Query Engine**: Custom query engine using hierarchical community summaries
# 6. **Testing**: Query the knowledge graph for insights

# %% [markdown]
# ---
#
# ## 🚀 Setup Instructions
#
# Follow these steps to set up the project environment before running the notebook.
#
# ### Prerequisites
# - Python 3.11+ installed
# - Docker installed and running
# - Git (optional, for cloning)
#
# ---
#
# ### Step 1: Create Python Environment
#
# **Using Conda (Recommended)**
# https://www.anaconda.com/docs/getting-started/miniconda/install
#
#
# ```bash
# # Create a new conda environment
# conda create -n graph-rag-demo python=3.11 -y
#
# # Activate the environment
# conda activate graph-rag-demo
# ```
# ---
#
# ### Step 2: Install Required Packages
#
# ```bash
#
# # install packages individually:
# pip install pandas llama-index llama-index-core
# pip install llama-index-llms-openrouter llama-index-embeddings-huggingface
# pip install llama-index-graph-stores-neo4j neo4j
# pip install networkx graspologic
# pip install nest-asyncio python-dotenv
# pip install sentence-transformers
# pip install docling
# ```
# ---
#
# ### Step 3: Set Up Environment Variables
#
# Create a `.env` file in the project root directory:
#
# ```bash
# # Create .env file (Windows PowerShell)
# New-Item -Path .env -ItemType File
#
# # Create .env file (Linux/Mac/Git Bash)
# touch .env
# ```
#
# Add your OpenRouter API key to the `.env` file:
# ```
# OPENROUTER_API_KEY=your_api_key_here
# ```
#
# **To get an OpenRouter API key:**
# 1. Go to [https://openrouter.ai/](https://openrouter.ai/)
# 2. Sign up or log in
# 3. Navigate to API Keys section
# 4. Create a new API key
# 5. Copy and paste it into your `.env` file
#
# ---
#
# ### Step 4: Set Up Neo4j Database with Docker
#
# **Run Neo4j with APOC plugin:**
#
# ```bash
# # Windows PowerShell
# docker run `
#   -p 7474:7474 -p 7687:7687 `
#   -v "$PWD/data:/data" -v "$PWD/plugins:/plugins" `
#   --name neo4j-apoc `
#   -e 'NEO4J_AUTH=neo4j/12345aA#' `
#   -e NEO4J_apoc_export_file_enabled=true `
#   -e NEO4J_apoc_import_file_enabled=true `
#   -e NEO4J_apoc_import_file_use__neo4j__config=true `
#   -e NEO4JLABS_PLUGINS='["apoc"]' `
#   neo4j:latest
# ```
#
# ```bash
# # Linux/Mac/Git Bash
# docker run \
#   -p 7474:7474 -p 7687:7687 \
#   -v "$PWD/data:/data" -v "$PWD/plugins:/plugins" \
#   --name neo4j-apoc \
#   -e 'NEO4J_AUTH=neo4j/12345aA#' \
#   -e NEO4J_apoc_export_file_enabled=true \
#   -e NEO4J_apoc_import_file_enabled=true \
#   -e NEO4J_apoc_import_file_use__neo4j__config=true \
#   -e NEO4JLABS_PLUGINS='["apoc"]' \
#   neo4j:latest
# ```
#
# **Access Neo4j Browser:**
# - Open browser: [http://localhost:7474](http://localhost:7474)
# - Username: `neo4j`
# - Password: `12345aA#`
#
# ---
#
# ### Step 5: Verify Setup
#
# Run this cell to verify all imports work:
#
# ```python
# import pandas as pd
# from llama_index.core import Document
# from llama_index.llms.openrouter import OpenRouter
# from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore
# import networkx as nx
# from graspologic.partition import hierarchical_leiden
# print("✅ All packages imported successfully!")
# ```
#
# ---
#
# ### ⚠️ Common Issues & Solutions
#
# **Issue: `graspologic` version error**
# ```bash
# pip install --upgrade graspologic
# ```
#
# **Issue: Neo4j connection failed**
# - Ensure Docker is running
# - Check if container is running: `docker ps`
# - Verify ports 7474 and 7687 are not in use
#
# **Issue: OpenRouter API key not found**
# - Check `.env` file exists in project root
# - Verify the key name is exactly `OPENROUTER_API_KEY`
# - Restart the notebook kernel after creating `.env`
#
# ---
#
# ### 📚 Resources
# - [LlamaIndex Documentation](https://docs.llamaindex.ai/)
# - [GraphRAG v2 Demo](https://developers.llamaindex.ai/python/examples/cookbooks/graphrag_v2/)
# - [Neo4j Documentation](https://neo4j.com/docs/)
# - [OpenRouter API](https://openrouter.ai/docs)
#
# ---

# %% [markdown]
# ## 1. Data Loading and Preparation
#
# Load news articles dataset from GitHub and convert it into LlamaIndex documents. We're using the first 50 articles to keep processing manageable.

# %%
# import pandas as pd
# from llama_index.core import Document

# news = pd.read_csv(
#     "https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/news_articles.csv"
# )[:50]

# news.head()

# %%
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import (
    PdfPipelineOptions,
    PictureDescriptionApiOptions,
)
from docling.document_converter import DocumentConverter, PdfFormatOption
from pydantic import AnyUrl, SecretStr
import os


def parse_document(
    input_doc_path,
    do_picture_description: bool = False,
    do_formula_enrichment: bool = False,
):
    api_key = SecretStr(os.environ["OPENROUTER_API_KEY"])
    model = "qwen/qwen-2-vl-7b-instruct"
    picture_desc_api_option = PictureDescriptionApiOptions(
        url=AnyUrl("https://openrouter.ai/api/v1/chat/completions"),
        prompt="Describe this image in sentences in a single paragraph.",
        params=dict(
            model=model,
        ),
        headers={
            "Authorization": f"Bearer {api_key.get_secret_value()}",
            "X-Title": "docling-pdf-parser",
        },
        timeout=60,
    )
    pipeline_options = PdfPipelineOptions(
        do_picture_description=do_picture_description,
        picture_description_options=picture_desc_api_option,
        enable_remote_services=True,
        generate_picture_images=True,
        do_formula_enrichment=do_formula_enrichment,
        images_scale=2,
    )

    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )
    conv_res = converter.convert(source=input_doc_path)
    return conv_res

# %% [markdown]
# ## 1.1 Document Parsing with Docling
#
# **Docling** is an advanced document parsing library that converts PDF files into structured text while preserving:
# - Layout and formatting information
# - Images and figures (with optional AI-based descriptions)
# - Mathematical formulas and equations
# - Tables and structured data
#
# ### Key Features of parse_document Function:
#
# - **Picture Description**: Uses OpenRouter API with vision models to generate natural language descriptions of images found in PDFs
# - **Formula Enrichment**: Optionally extracts and processes mathematical formulas
# - **High-Resolution Image Processing**: Scales images (2x) for better quality
# - **Configurable Pipeline**: Flexible options for enabling/disabling specific features
#
# This makes it ideal for academic papers, research documents, and technical content where preserving structure and context is crucial.

# %%
from pathlib import Path

file = Path("./paper/short-paper-with-formula-and-image.pdf")

source = file
result = parse_document(file, do_picture_description=True, do_formula_enrichment=False)
# Out:
# [INFO] 2026-01-18 23:23:55,190 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-18 23:23:55,191 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-18 23:23:55,227 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-18 23:23:55,230 [RapidOCR] main.py:50: Using C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-18 23:23:55,560 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-18 23:23:55,561 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-18 23:23:55,565 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-18 23:23:55,566 [RapidOCR] main.py:50: Using C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-18 23:23:55,692 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-18 23:23:55,694 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-18 23:23:55,757 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-18 23:23:55,759 [RapidOCR] main.py:50: Using C:\Users\BUITOFU\anaconda3\envs\graphrag_clean\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth

# %% [markdown]
# ### Parse PDF Document
#
# Load and parse a PDF file using the Docling document converter:
# - **Input**: PDF file path from the `paper/` directory
# - **Processing**: Extracts text, images, and structure
# - **Picture Description**: Enabled to generate AI descriptions for images in the PDF
# - **Formula Enrichment**: Disabled (can be enabled if needed)
#
# The parsed result contains the document structure which will be converted to plain text for knowledge graph extraction.

# %% [markdown]
# ### Convert to LlamaIndex Documents
#
# Transform the pandas DataFrame into LlamaIndex `Document` objects, combining title and text for each article.

# %%
# documents = [
#     Document(text=f"{row['title']}: {row['text']}") for i, row in news.iterrows()
# ]

# %% [markdown]
# ## 2. LLM Configuration
#
# Configure the Large Language Model using OpenRouter with GPT-4o-mini. This LLM will be used for:
# - Extracting entities and relationships from text
# - Generating community summaries
# - Answering user queries

# %%
from dotenv import load_dotenv
import os

load_dotenv()

from llama_index.llms.openrouter import OpenRouter
from llama_index.core.llms import ChatMessage

llm = OpenRouter(
    model="openai/gpt-4o-mini",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    max_tokens=1024,
    context_window=2048,
    temperature=0.1,
    timeout=60.0,
)

from llama_index.core import Settings

Settings.llm = llm

# %% [markdown]
# ## 3. Custom Graph Extractor Implementation
#
# ### GraphRAGExtractor Class
#
# This custom extractor extends LlamaIndex's `TransformComponent` to extract knowledge graph triplets (entity-relation-entity) from text chunks using an LLM.
#
# **Key Features:**
# - **Async Processing**: Uses asyncio for parallel extraction across multiple nodes
# - **Flexible Prompting**: Customizable extraction prompt
# - **Entity Extraction**: Identifies entities with types and descriptions
# - **Relationship Extraction**: Discovers relationships between entities with descriptions
# - **Metadata Management**: Stores extracted graph data in node metadata

# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from typing import Any, List, Callable, Optional, Union, Dict
from IPython.display import Markdown, display

from llama_index.core.async_utils import run_jobs
from llama_index.core.indices.property_graph.utils import (
		default_parse_triplets_fn,
)
from llama_index.core.graph_stores.types import (
		EntityNode,
		KG_NODES_KEY,
		KG_RELATIONS_KEY,
		Relation,
)
from llama_index.core.llms.llm import LLM
from llama_index.core.prompts import PromptTemplate
from llama_index.core.prompts.default_prompts import (
		DEFAULT_KG_TRIPLET_EXTRACT_PROMPT,
)
from llama_index.core.schema import TransformComponent, BaseNode
from llama_index.core.bridge.pydantic import BaseModel, Field

class GraphRAGExtractor(TransformComponent):
	"""Extract triples from a graph.

		Uses an LLM and a simple prompt + output parsing to extract paths (i.e. triples) and entity, relation descriptions from text.

		Args:
				llm (LLM):
						The language model to use.
				extract_prompt (Union[str, PromptTemplate]):
						The prompt to use for extracting triples.
				parse_fn (callable):
						A function to parse the output of the language model.
				num_workers (int):
						The number of workers to use for parallel processing.
				max_paths_per_chunk (int):
						The maximum number of paths to extract per chunk.
	"""

	llm: LLM 
	extract_prompt: PromptTemplate 
	parse_fn: Callable 
	num_workers: int 
	max_paths_per_chunk: int 

	def __init__(
		self,
		llm: Optional[LLM] = None,
		extract_prompt: Optional[Union[str, PromptTemplate]] = None,
		parse_fn: Callable = default_parse_triplets_fn,
		max_paths_per_chunk: int = 10,
		num_workers: int = 4,
	)-> None: 
		from llama_index.core import Settings

		if isinstance(extract_prompt, str):
				extract_prompt = PromptTemplate(extract_prompt)
		
		super().__init__(
			 llm=llm or Settings.llm,
						extract_prompt=extract_prompt or DEFAULT_KG_TRIPLET_EXTRACT_PROMPT,
						parse_fn=parse_fn,
						num_workers=num_workers,
						max_paths_per_chunk=max_paths_per_chunk,
		)

	@classmethod
	def class_name(cls) -> str:
		return "GraphExtractor"
	
	def __call__(
			self, nodes: List[BaseNode], show_progress: bool = False, **kwargs: Any
	) -> List[BaseNode]:
		"""Extract triplets from nodes."""
		return asyncio.run(
						self.acall(nodes, show_progress=show_progress, **kwargs)
				)
	
	async def _aextract(
			self, node: BaseNode
	) -> BaseNode:
		"""Extract triples from a node."""
		assert hasattr(node, "text")
		
		text = node.get_content(metadata_mode="llm")
		try: 
				llm_response = await self.llm.apredict(
						self.extract_prompt,
						text = text,
						max_knowledge_triplets = self.max_paths_per_chunk,
				)

				entities, entities_relationship = self.parse_fn(llm_response)
		except ValueError:
				entities = []
				entities_relationship = []

		existing_nodes = node.metadata.pop(KG_NODES_KEY, [])
		existing_relations = node.metadata.pop(KG_RELATIONS_KEY, [])
		entity_metadata = node.metadata.copy()
		
		for entity, entity_type, description in entities:
			# normalize label
			if isinstance(entity_type, list):
				if len(entity_type) == 0:
					label = "Entity"
				else:
					label = entity_type[0]
			else:
				label = entity_type

			entity_metadata["entity_description"] = description
			entity_metadata["types"] = entity_type
			entity_node = EntityNode(
				name=str(entity),
				label=str(label),
				properties=entity_metadata
			)
			existing_nodes.append(entity_node)

		relation_metadata = node.metadata.copy()
		
		for triplet in entities_relationship: 
			subj, obj, rel, description = triplet
			relation_metadata["relationship_description"] = description
			relation = Relation(
				label = rel,
				source_id = subj,
				target_id = obj,
				properties = relation_metadata
			)
			existing_relations.append(relation)
		
		node.metadata[KG_NODES_KEY] = existing_nodes
		node.metadata[KG_RELATIONS_KEY] = existing_relations
		return node



	async def acall(
		self, nodes: List[BaseNode], show_progress: bool = False, **kwargs: Any
		) -> List[BaseNode]:
		jobs = []
		for node in nodes: 
				jobs.append(self._aextract(node))
		return await run_jobs(
			jobs,
			show_progress,
			desc="Extracting paths from text"
		)

# %% [markdown]
# ## 4. Custom Graph Store with Community Detection
#
# ### GraphRAGStore Class
#
# Extends Neo4j Property Graph Store with community detection and summarization capabilities using the Hierarchical Leiden algorithm.
#
# **Key Features:**
# - **Community Detection**: Groups related entities into communities using hierarchical Leiden clustering
# - **Community Summarization**: Uses LLM to generate natural language summaries for each community
# - **NetworkX Integration**: Converts graph to NetworkX format for analysis
# - **Multi-community Membership**: Entities can belong to multiple communities
# - **Relationship Aggregation**: Collects all relationships within each community

# %%
import re
import networkx as nx
from graspologic.partition import hierarchical_leiden
from collections import defaultdict

from llama_index.core.llms import ChatMessage
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore


class GraphRAGStore(Neo4jPropertyGraphStore):

    def __init__(self, *args, llm=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.llm = llm
        self.community_summary = {}
        self.entity_info = None
        self.max_cluster_size = 5
    
    def generate_community_summary(self, text):
        """Generate summary for a given text using an LLM."""
        messages = [
            ChatMessage(
                role="system",
                content=(
                    "You are provided with a set of relationships from a knowledge graph, each represented as "
                    "entity1->entity2->relation->relationship_description. Your task is to create a summary of these "
                    "relationships. The summary should include the names of the entities involved and a concise synthesis "
                    "of the relationship descriptions. The goal is to capture the most critical and relevant details that "
                    "highlight the nature and significance of each relationship. Ensure that the summary is coherent and "
                    "integrates the information in a way that emphasizes the key aspects of the relationships."
                ),
            ),
            ChatMessage(role="user", content=text),
        ]
        response = self.llm.chat(messages)
        clean_response = re.sub(r"^assistant:\s*", "", str(response)).strip()
        return clean_response

    def build_communities(self):
        """Builds communities from the graph and summarizes them."""
        nx_graph = self._create_nx_graph()
        community_hierarchical_clusters = hierarchical_leiden(
            nx_graph, max_cluster_size=self.max_cluster_size
        )
        self.entity_info, community_info = self._collect_community_info(
            nx_graph, community_hierarchical_clusters
        )
        self._summerize_communites(community_info)

    def _create_nx_graph(self):
        """Converts internal graph representation to NetworkX graph."""
        nx_graph = nx.Graph()
        triplets = self.get_triplets()
        for entity1, relation, entity2 in triplets:
            nx_graph.add_node(entity1.name)
            nx_graph.add_node(entity2.name)
            nx_graph.add_edge(
                relation.source_id,
                relation.target_id,
                relationship=relation.label,
                description=relation.properties.get("relationship_description", ""),
            )
        return nx_graph

    def _collect_community_info(self, nx_graph, clusters):
        """Collect information for each node based on their community,
        allowing entities to belong to multiple clusters."""
        entity_info = defaultdict(set)
        community_info = defaultdict(list)

        for item in clusters:
            node = item.node
            cluster_id = item.cluster

            # update entity_info
            entity_info[node].add(cluster_id)

            for neighbor in nx_graph.neighbors(node):
                edge_data = nx_graph.get_edge_data(node, neighbor)
                if edge_data:
                    detail = f"{node} -> {neighbor} -> {edge_data['relationship']} -> {edge_data['description']}"
                    community_info[cluster_id].append(detail)
        # Convert sets to lists for easier serialization if needed
        entity_info = {k: list(v) for k, v in entity_info.items()}
        return dict(entity_info), dict(community_info)

    #     community_info = {
    #     0: [
    #         "Apple -> Beats -> ACQUIRED -> Apple acquired Beats in 2014",
    #         "Apple -> iPhone -> PRODUCED -> iPhone is a smartphone",
    #         "Beats -> Headphones -> IS_A -> Beats produces headphones"
    #     ]
    # 	}
    ###sau
    # community_summary = {
    #     0: "Apple is a technology company that acquired Beats in 2014 and produces consumer electronics such as the iPhone. Beats is known for producing headphones.",
    #     1: "Google developed TensorFlow, a machine learning framework widely used for machine learning tasks."
    # }

    def _summerize_communites(self, community_info):
        """Generate and store summaries for each community."""
        for community_id, details in community_info.items():
            details_text = "\n".join(details) + "."
            self.community_summary[community_id] = self.generate_community_summary(
                details_text
            )

    def get_community_summaries(self):
        """Returns the community summaries, building them if not already done."""
        if not self.community_summary:
            self.build_communities()
        return self.community_summary

# %% [markdown]
# ## 5. Custom Query Engine
#
# ### GraphRAGQueryEngine Class
#
# Implements a custom query engine that leverages community summaries for answering questions.
#
# **Query Process:**
# 1. **Entity Retrieval**: Find relevant entities from the query using similarity search
# 2. **Community Mapping**: Identify communities that contain these entities
# 3. **Community-based Answering**: Generate answers from each relevant community summary
# 4. **Answer Aggregation**: Combine individual community answers into a final coherent response
#
# This approach provides more comprehensive answers by considering the broader context of entity communities.

# %%
from click import prompt
from llama_index.core.query_engine import CustomQueryEngine
from llama_index.core.llms import LLM
from llama_index.core import PropertyGraphIndex

import re

from typer import prompt

class GraphRAGQueryEngine(CustomQueryEngine):
    graph_store: GraphRAGStore
    index: PropertyGraphIndex
    llm: LLM
    similarity_top_k: int = 20
    
    def custom_query(self, query_str):
        """Process all community summaries to generate answers to a specific query."""
        
        entities = self.get_entities(query_str, self.similarity_top_k)
        
        community_ids = self.retrieve_entity_communities(
			self.graph_store.entity_info, entities
		)
        community_summaries = self.graph_store.get_community_summaries()
        
        community_answers = [
			self.generate_answer_from_summary(community_summary, query_str)
			for id, community_summary in community_summaries.items()
			if id in community_ids
		]
        
        final_answer = self.aggregate_answers(community_answers)
        
        return final_answer
    
    def get_entities(self, query_str, similarity_top_k):
        nodes_retrieved = self.index.as_retriever(
			similarity_top_k = similarity_top_k
		).retrieve(query_str)
        
        entities = set ()
        
        # pattern  entity -> rel -> entity
        pattern = (
            r"^(\w+(?:\s+\w+)*)\s*->\s*([a-zA-Z\s]+?)\s*->\s*(\w+(?:\s+\w+)*)$"
        )
        
        for node in nodes_retrieved: 
            matches = re.findall(
				pattern, node.text, re.MULTILINE | re.IGNORECASE
			)
            
            for match in matches: 
                subject = match[0]
                obj = match[2]
                entities.add(subject)
                entities.add(obj)
        return list(entities)
  
    def retrieve_entity_communities(self, entity_info, entities):
        community_ids = []

        for entity in entities:
            if entity in entity_info:
                community_ids.extend(entity_info[entity])

        return list(set(community_ids))
    
    
    def generate_answer_from_summary(self, community_summary, query):
        """Generate an answer from a community summary based on a given query using LLM."""
        prompt = f"""
            Answer the question below as if you are responding directly to a user.

            Guidelines:
            - Do NOT mention or refer to any internal processes, summaries, or intermediate data.
            - Do NOT use phrases such as "community summary", "based on the information above",
            "the provided data", "no community", or similar meta expressions.
            - Provide a natural, confident answer.
            - Reasoning and inference are allowed, but must remain implicit.

            Question:
            {query}
            """


        messages = [
            ChatMessage(role="system", content=community_summary),
            ChatMessage(role="user", content=prompt),
        ]
        response = self.llm.chat(messages)
        cleaned_response = re.sub(r"^assistant:\s*", "", str(response)).strip()
        return cleaned_response
    
    def aggregate_answers(self, community_answers):
        """Aggregate individual community answers into a final, coherent response."""
        # intermediate_text = " ".join(community_answers)
        prompt = """
            You are responding to a user question based on user given context.

            Instructions:
            - Produce a single final answer.
            - Do NOT mention combining, aggregating, or synthesizing.
            - Do NOT refer to previous answers or internal steps.
            - The response must read as a direct standalone answer.
            """

        messages = [
            ChatMessage(role="system", content=prompt),
            ChatMessage(
                role="user",
                content=f"Intermediate answers: {community_answers}",
            ),
        ]
        final_response = self.llm.chat(messages)
        cleaned_final_response = re.sub(
            r"^assistant:\s*", "", str(final_response)
        ).strip()
        return cleaned_final_response

# %% [markdown]
# ## 6. Text Chunking
#
# Split documents into smaller chunks for more granular entity extraction. Using:
# - **Chunk size**: 1024 characters
# - **Overlap**: 20 characters to maintain context across chunks

# %%
from llama_index.core import Document
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=20,
)
# pdf_document to text (test)
pdf_document = result.document.export_to_text()


documents = [Document(text=pdf_document)]


nodes = splitter.get_nodes_from_documents(documents)
nodes

len(nodes)
# Out:
# Parameter `strict_text` has been deprecated and will be ignored.
# 8

# %% [markdown]
# ## 7. Custom Extraction Prompt
#
# Define a detailed prompt template for knowledge graph triplet extraction.
#
# **Prompt Instructions:**
# - Identify entities with names, types, and descriptions
# - Find relationships between entity pairs
# - Return structured JSON output with entities and relationships
# - Extract up to `max_knowledge_triplets` per chunk
#
# This prompt ensures consistent, structured output for reliable parsing.

# %%
# KG_TRIPLET_EXTRACT_TMPL = """
# -Goal-
# Given a text document, identify entities and relationships to construct a knowledge graph.
# Each extraction MUST be centered around exactly ONE Paper entity, which acts as the anchor node.
# All extracted entities and relationships MUST be directly or indirectly connected to this Paper.

# Extract up to {max_knowledge_triplets} entity-relation triplets.

# You MUST strictly follow the predefined knowledge graph schema described below.

# -Predefined Knowledge Graph Schema-

# MAIN Entity Types (ONLY these types are allowed):
# - Paper
# - Section
# - Argument
# - Claim
# - Evidence
# - Concept
# - Background
# - Author

# IMPORTANT:
# - Subtypes are NOT allowed.
# - Do NOT encode any subtype information in entity_type.
# - If the text implies a subtype (e.g. table, figure, dataset), capture it ONLY in entity_description.

# Allowed Relationships (directional, fixed):

# Paper-centered relationships (Paper is the anchor):
# - Paper -> Section : has
# - Paper -> Background : has
# - Paper -> Paper : cites
# - Author -> Paper : wrote

# Structural relationships:
# - Section -> Concept : mentions
# - Section -> Argument : contains
# - Argument -> Claim : has
# - Claim -> Evidence : supported_by

# Concept relationships:
# - Concept -> Concept : related_to

# Schema Enforcement Rules:
# - Exactly ONE Paper entity MUST exist in the output.
# - Every entity MUST be connected (directly or indirectly) to the Paper entity.
# - Do NOT invent entity types outside the allowed list.
# - Do NOT invent relationships.
# - Relationship direction MUST match the schema.
# - Do NOT extract isolated entities.
# - If information does not fit the schema, do NOT extract it.

# -Steps-
# 1. Identify the single Paper entity (anchor).
# 2. Identify all other entities that relate to this Paper.
# For each entity, extract:
# - entity_name: Name of the entity, capitalized
# - entity_type: One of the allowed MAIN entity types
# - entity_description: Description of the entity's role in the document

# 3. Identify relationships.
# Extract ONLY schema-compliant relationships.
# For each relationship:
# - source_entity: name of the source entity
# - target_entity: name of the target entity
# - relation: EXACT relationship name from the allowed list
# - relationship_description: Explanation grounded in the text

# 4. Validation:
# - Ensure there is exactly ONE Paper entity.
# - Ensure the Paper acts as the anchor of the graph.
# - Ensure all Concept-to-Concept links use ONLY `related_to`.

# -Output Formatting-
# - Return valid JSON with two keys: 'entities' and 'relationships'
# - No text outside JSON
# - If nothing valid is found, return:
#   { "entities": [], "relationships": [] }

# ****IMPORTANT****
# - Return ONLY valid JSON.
# - Do NOT include explanations, comments, or markdown.
# - The response must start with '{' and end with '}'.

# -Real Data-
# ######################
# text: {text}
# ######################
# output:
# """

KG_TRIPLET_EXTRACT_TMPL = """
-Context-
The input text is a CHUNK of a larger document.
Multiple extractions may be performed on different chunks of the SAME document.

You MUST assume:
- All chunks from the same document refer to ONE and ONLY ONE Paper entity.
- The Paper entity identity MUST be logically consistent across all chunks.
- You are NOT allowed to create multiple Paper entities for the same document.

-Goal-
Given a text chunk, extract entities and relationships to construct a knowledge graph.
Each extraction MUST be centered around exactly ONE Paper entity, which acts as the anchor node.
All extracted entities and relationships MUST be directly or indirectly connected to this Paper.

Extract up to {max_knowledge_triplets} entity-relation triplets.

You MUST strictly follow the predefined knowledge graph schema described below.

-Predefined Knowledge Graph Schema-

MAIN Entity Types (ONLY these types are allowed):
- Paper
- Reference
- Section
- Argument
- Claim
- Evidence
- Concept
- Background
- Author

IMPORTANT TYPE RULES:
- Subtypes are NOT allowed.
- Do NOT encode any subtype information in entity_type.
- If the text implies a subtype (e.g. table, figure, dataset), capture it ONLY in entity_description.

Allowed Relationships (directional, fixed):

Paper-centered relationships:
- Paper -> Section : has
- Paper -> Reference : cites
- Paper -> Background : has
- Paper -> Paper : cites
- Author -> Paper : wrote

Structural relationships:
- Section -> Concept : mentions
- Section -> Argument : contains
- Argument -> Claim : has
- Claim -> Evidence : supported_by

Concept relationships:
- Concept -> Concept : related_to

CRITICAL IDENTITY & CONNECTIVITY RULES:
- Exactly ONE Paper entity MUST exist in the output.
- If the paper title is explicitly stated, use it verbatim as entity_name.
- If the title is NOT stated, use a single generic name:
  "Unknown Paper (Derived from Document Context)"
- You MUST reuse the SAME Paper entity_name consistently.
- Every extracted entity MUST be connected to the Paper entity by at least one relationship path.
- If an entity cannot be connected to the Paper, do NOT extract it.
- Do NOT create disconnected subgraphs.

-Schema Enforcement Rules-
- Do NOT invent entity types outside the allowed list.
- Do NOT invent relationships.
- Relationship direction MUST match the schema exactly.
- Do NOT extract isolated entities.

-Steps-
1. Identify the canonical Paper entity for the document.
   - Normalize the paper identity so it remains stable across chunks.
2. Identify all other entities that relate to this Paper.
For each entity, extract:
- entity_name: Name of the entity, capitalized
- entity_type: One of the allowed MAIN entity types
- entity_description: Description of the entity's role in the document

3. Identify relationships.
Extract ONLY schema-compliant relationships.
For each relationship:
- source_entity: name of the source entity
- target_entity: name of the target entity
- relation: EXACT relationship name from the allowed list
- relationship_description: Explanation grounded in the text

4. Final Validation (MANDATORY):
- There is exactly ONE Paper entity.
- All entities are connected (directly or indirectly) to the Paper.
- No disconnected clusters exist.
- All Concept-to-Concept links use ONLY `related_to`.

-An Output Example-
{
  "entities": [
    {
      "entity_name": "Attention Is All You Need",
      "entity_type": "Paper",
      "entity_description": "The main research paper discussing the Transformer architecture."
    },
    {
      "entity_name": "Introduction",
      "entity_type": "Section",
      "entity_description": "The section introducing the motivation and context of the paper."
    },
    {
      "entity_name": "Transformer Model",
      "entity_type": "Concept",
      "entity_description": "A neural network architecture based on self-attention mechanisms."
    },
    {
      "entity_name": "Vaswani et al. 2017",
      "entity_type": "Reference",
      "entity_description": "A cited work introducing the Transformer architecture."
    }
  ],
  "relationships": [
    {
      "source_entity": "Attention Is All You Need",
      "target_entity": "Introduction",
      "relation": "has",
      "relationship_description": "The paper contains an introduction section."
    },
    {
      "source_entity": "Introduction",
      "target_entity": "Transformer Model",
      "relation": "mentions",
      "relationship_description": "The introduction mentions the Transformer model."
    },
    {
      "source_entity": "Attention Is All You Need",
      "target_entity": "Vaswani et al. 2017",
      "relation": "cites",
      "relationship_description": "The paper cites the original work that proposed the Transformer model."
    }
  ]
}

-Output Formatting-
- Return valid JSON with two keys: 'entities' and 'relationships'
- No text outside JSON
- The response MUST start with '{' and end with '}'
- If nothing valid is found, return:
  { "entities": [], "relationships": [] }

-Real Data-
######################
text: {text}
######################
output:
"""

# %% [markdown]
# ## 8. JSON Parser and Extractor Initialization
#
# ### Custom Parse Function
#
# Parses LLM responses to extract structured entity and relationship data:
# - Removes markdown formatting (```json blocks)
# - Extracts JSON content using regex
# - Handles parsing errors gracefully
# - Logs raw responses for debugging
#
# ### Initialize GraphRAGExtractor
#
# Configure the extractor with:
# - Custom LLM
# - Custom extraction prompt
# - Maximum 3 triplets per chunk
# - Custom parsing function

# %%
import json, re
from typing import List, Tuple


def parse_fn(response_str: str) -> Tuple[List, List]:
    entities, relationships = [], []

    # 1. strip markdown
    response_str = re.sub(r"```json", "", response_str, flags=re.IGNORECASE)
    response_str = re.sub(r"```", "", response_str)

    response_str = response_str.strip()
    with open("raw.txt", "w", encoding="utf-8") as f:
        f.write(response_str + "\n")

    # 2. extract JSON block (non-greedy)
    match = re.search(r"\{[\s\S]*\}", response_str)
    if not match:
        return entities, relationships

    json_str = match.group(0)

    # 3. parse
    try:
        data = json.loads(json_str)
    except json.JSONDecodeError:
        return entities, relationships

    for e in data.get("entities", []):
        raw_type = e.get("entity_type")

        # Normalize entity_type → List[str]
        if isinstance(raw_type, str):
            # "Section:Abstract" -> ["Section", "Abstract"]
            entity_types = [t.strip() for t in raw_type.split(":") if t.strip()]
        elif isinstance(raw_type, list):
            # already a list (future-proof)
            entity_types = raw_type
        else:
            entity_types = []
        entities.append(
            (
                e.get("entity_name"),
                entity_types,
                e.get("entity_description"),
            )
        )

    for r in data.get("relationships", []):
        relationships.append(
            (
                r.get("source_entity"),
                r.get("target_entity"),
                r.get("relation"),
                r.get("relationship_description"),
            )
        )

    return entities, relationships


kg_extractor = GraphRAGExtractor(
    llm=llm,
    extract_prompt=KG_TRIPLET_EXTRACT_TMPL,
    max_paths_per_chunk=8,
    parse_fn=parse_fn,
)

# %% [markdown]
# ## 9. Embedding Model Setup
#
# Initialize HuggingFace embedding model for semantic similarity search. Using `sentence-transformers/all-MiniLM-L6-v2`:
# - Lightweight and fast
# - Good balance between performance and speed
# - Used for entity retrieval during queries

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %% [markdown]
# ## 10. Graph Store Initialization
#
# Initialize the custom `GraphRAGStore` connected to Neo4j database:
# - **Database**: Neo4j running on localhost:7687
# - **Features**: Community detection and summarization capabilities
# - **Storage**: Persists graph data for reuse

# %%
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore

# Note: used to be `Neo4jPGStore`
graph_store = GraphRAGStore(
    llm=llm, username="neo4j", password="12345aA#", url="bolt://localhost:7687"
)

# %% [markdown]
# ## 11. Build Property Graph Index
#
# **Main Processing Step**: Construct the knowledge graph by:
# 1. Processing each text chunk with the graph extractor
# 2. Extracting entities and relationships using the LLM
# 3. Storing graph data in Neo4j
# 4. Creating embeddings for semantic search
#
# ⚠️ **Note**: This step may take several minutes as it processes all documents and makes multiple LLM calls.

# %%
from llama_index.core import PropertyGraphIndex


index = PropertyGraphIndex(
    nodes=[],
    kg_extractors=[kg_extractor],
    property_graph_store=graph_store,
    embed_model=embed_model,
    show_progress=True,
    llm=llm,
)

# %%
#Ingest new document everytime needed

index.build_index_from_nodes(nodes)
# Out:
# Extracting paths from text: 100%|██████████| 8/8 [00:23<00:00,  2.98s/it]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Generating embeddings: 100%|██████████| 6/6 [00:00<00:00, 10.58it/s]
# IndexLPG(index_id='af9f67de-989a-48a2-8105-1002684b3911', summary=None)

# %% [markdown]
# ---
#
# ## 12. Graph Analysis and Querying
#
# The following cells demonstrate how to analyze the constructed knowledge graph and query it for insights.

# %% [markdown]
# ### Inspect Graph Triplets
#
# Examine a sample triplet from the knowledge graph to understand the extracted relationships and their properties.

# %%
index.property_graph_store.get_triplets()[7][1].properties
# Out:
# {'triplet_source_id': '1068c79e-abba-412d-9aa4-bc452ab77809',
#  'relationship_description': 'Garner is referenced as the author of the work discussing the canonical signed-digit code.'}

# %% [markdown]
# ### Build Communities
#
# Execute community detection and generate summaries for each community. This step:
# - Applies hierarchical Leiden clustering
# - Groups entities into communities
# - Generates natural language summaries using the LLM

# %%
index.property_graph_store.build_communities()

# %% [markdown]
# ### Initialize Query Engine
#
# Create the custom query engine with:
# - Reference to the graph store
# - LLM for answer generation
# - Similarity search with top 10 results

# %%
query_engine = GraphRAGQueryEngine(
    graph_store=index.property_graph_store,
    llm=llm,
    index=index,
    similarity_top_k=10,
)

# %% [markdown]
# ### Query 1: Energy Sector News
#
# Ask the graph about energy sector news. The query engine will:
# 1. Find entities related to "energy sector"
# 2. Retrieve relevant community summaries
# 3. Generate a comprehensive answer

# %%
response = query_engine.query("What are the main authors in the paper?")
display(Markdown(f"{response.response}"))
# Out:
# The main authors in the paper are not mentioned in the provided information.

# %% [markdown]
# ### Query 2: Main News Overview
#
# Broad query to understand the main topics discussed across all documents.

# %%
response = query_engine.query("What are the main topics discussed in the document?")
display(Markdown(f"{response.response}"))
# Out:
# The document discusses several key topics, including the REITWIESNER algorithm and its modification, REITWIESNERMODIFIED, along with the GARNERREVISITED algorithm. It covers the conversion of conventional binary numbers, the canonical signed-digit code, and the performance evaluations of various algorithms such as Algorithm 5, Algorithm 9, Algorithm 10, STRING_0, and STRING_1. Additionally, it explores the relationships between these algorithms, particularly focusing on the simplification of Algorithm 5 by Algorithm 9, and the implications of the findings related to the REITWIESNERMODIFIED algorithm as presented in Algorithm 8 and the conclusions section. Section 5 is highlighted for its elaboration on Algorithm 9 and the overall analysis of algorithmic performance.

# %%
response_2 = query_engine.query(
    "Which themes connect the technology and geopolitics articles in the dataset"
)
display(Markdown(f"{response_2.response}"))
# Out:
# The provided information does not contain any details regarding technology and geopolitics articles or their themes.

# %% [markdown]
# ### View All Community Summaries
#
# Display all generated community summaries to understand the different topic clusters discovered in the corpus.

# %%
for cid, summary in index.property_graph_store.community_summary.items():
    print(f"\n===== COMMUNITY {cid} =====")
    print(summary)
# Out:
# ===== COMMUNITY 0 =====
# The relationships outlined in the knowledge graph highlight the connections between various components of a paper focused on the conversion of nonnegative integers to the canonical signed-digit representation.
#
# 1. **A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION** has a **LITERATURE REVIEW** that discusses methods for canonical signed-digit conversion, indicating that this section is crucial for understanding the existing techniques in the field.
#
# 2. The **LITERATURE REVIEW** also references **REITWIESNER'S METHOD**, emphasizing its significance in the context of signed-digit conversion. This suggests that Reitwiesner's method is a notable approach within the broader discussion of conversion methods.
#
# Overall, the summary underscores the importance of the literature review in providing a comprehensive overview of canonical signed-digit conversion methods, with a specific mention of Reitwiesner's method as a key reference point in the discussion.
#
# ===== COMMUNITY 1 =====
# The relationships among the entities can be summarized as follows:
#
# 1. **NAF ALGORITHM** and **ALGORITHM 4**: The NAF algorithm paper includes a section that describes Algorithm 4, indicating a direct reference and connection between the two.
#
# 2. **ALGORITHM 4** and **CANONICAL SIGNED-DIGIT REPRESENTATION**: Algorithm 4 mentions the canonical signed-digit representation as part of its description, highlighting its relevance in the context of the algorithm's functionality.
#
# Overall, the NAF algorithm is closely linked to Algorithm 4, which in turn incorporates the canonical signed-digit representation, showcasing the interrelated nature of these concepts in the field of algorithms.
#
# ===== COMMUNITY 2 =====
# The relationships among the entities can be summarized as follows:
#
# 1. **Algorithm 9 and Algorithm 5**: Algorithm 9 discusses the simplification of Algorithm 5, indicating a direct relationship where Algorithm 9 builds upon or refines Algorithm 5.
#
# 2. **Algorithm 9 and Section 5**: Section 5 contains a discussion on Algorithm 9, suggesting that this section is dedicated to elaborating on the concepts presented in Algorithm 9.
#
# 3. **Algorithm 5 and Algorithm 10**: Algorithm 5 is referenced in the context of Algorithm 10, showing that Algorithm 10 relies on or relates to the principles established in Algorithm 5.
#
# 4. **Section 5 and the Paper**: The paper includes Section 5, which discusses performance evaluation, highlighting the significance of this section within the broader context of the paper.
#
# Overall, the relationships illustrate a network of dependencies where Algorithms 9 and 5 are closely linked, with Section 5 serving as a critical component of the paper that evaluates the performance of these algorithms. Algorithm 10 also connects back to Algorithm 5, reinforcing its foundational role in the discussion.
#
# ===== COMMUNITY 3 =====
# The relationships among the entities can be summarized as follows:
#
# - **Algorithm 11** and **Table 2**: Algorithm 11 contains references to the rules for converting binary numbers as detailed in Table 2. This relationship is reciprocal, as Table 2 also contains references to Algorithm 11.
#
# - **Algorithm 12** and **Table 2**: Similarly, Algorithm 12 contains references to the rules for converting binary numbers as outlined in Table 2, which again is a reciprocal relationship, with Table 2 referencing Algorithm 12.
#
# In summary, both Algorithm 11 and Algorithm 12 are linked to Table 2, which serves as a source for the rules regarding binary number conversion, highlighting the interdependence of these algorithms and the table.
#
# ===== COMMUNITY 4 =====
# ### Summary of Relationships
#
# 1. **REITWIESNER and Table 1**: The paper includes Table 1, which presents rules for converting conventional binary numbers.
#
# 2. **REITWIESNER and REITWIESNERMODIFIED**: REITWIESNERMODIFIED is derived from the REITWIESNER algorithm, indicating a direct relationship of evolution or improvement.
#
# 3. **REITWIESNER and GARNE**: Garner is referenced as the author discussing the canonical signed-digit code, highlighting his contribution to the field.
#
# 4. **REITWIESNERMODIFIED and GARNERREVISITED**: GARNERREVISITED improves the performance of the REITWIESNER algorithm, showing a progression in algorithm development.
#
# 5. **REITWIESNERMODIFIED and Algorithm 8**: Algorithm 8 represents the REITWIESNERMODIFIED concept, linking the algorithm to its theoretical foundation.
#
# 6. **REITWIESNERMODIFIED and Conclusions**: The conclusions section discusses the REITWIESNERMODIFIED algorithm, summarizing its significance.
#
# 7. **GARNERREVISITED and Algorithm 10**: Algorithm 10 represents the GARNERREVISITED concept, indicating its formalization in the paper.
#
# 8. **GARNERREVISITED and Conclusions**: The conclusions section mentions the GARNERREVISITED algorithm, emphasizing its relevance.
#
# 9. **Algorithm 10 and Algorithm 9**: Algorithm 10 is derived from Algorithm 9, showing a lineage of development.
#
# 10. **Algorithm 9 and Algorithm 3**: Algorithm 9 is derived from Algorithm 3, indicating a progression in algorithmic design.
#
# 11. **Performance Evaluation and Discussion**: This section discusses multiple algorithms, including Algorithms 5, 9, and 10, as well as STRING_0, providing a comprehensive evaluation of their performance.
#
# 12. **STRING_0 and Conclusions**: The conclusions section mentions the STRING_0 algorithm, indicating its importance in the overall findings.
#
# 13. **Algorithm 5 and bin2naf Algorithm**: The section on Algorithm 5 mentions the bin2naf algorithm, linking it to the broader context of binary conversion techniques.
#
# 14. **Algorithm 5 and Algorithm 3**: Algorithm 5 is related to Algorithm 3, showing a connection in their development.
#
# This summary encapsulates the key relationships and their significance within the context of the paper, highlighting the evolution of algorithms and their contributions to the field of binary number conversion.
#
# ===== COMMUNITY 5 =====
# The relationships summarized from the knowledge graph are as follows:
#
# 1. **Algorithm 11** is associated with an **Unknown Paper**, which contains a section that describes Algorithm 11. Additionally, Algorithm 11 discusses the **Canonical Signed-Digit Representation**.
#
# 2. **Algorithm 12** is similarly linked to an **Unknown Paper**, which also contains a section that describes Algorithm 12. Like Algorithm 11, Algorithm 12 discusses the **Canonical Signed-Digit Representation**.
#
# 3. The **Canonical Signed-Digit Representation** is explicitly mentioned in relation to both Algorithm 11 and Algorithm 12, indicating that both algorithms provide insights into this representation.
#
# In summary, both Algorithm 11 and Algorithm 12 are detailed in separate unknown papers and both focus on the topic of Canonical Signed-Digit Representation, highlighting their relevance in this area of study.
#
# ===== COMMUNITY 6 =====
# The relationships highlight the interconnectedness of binary arithmetic, carry-out sequences, and full adders.
#
# 1. **Binary Arithmetic and Carry-Out Sequence**: The carry-out sequence is a significant aspect of binary arithmetic, as discussed in the relevant paper.
#
# 2. **Carry-Out Sequence and Full Adder**: The carry-out sequence is generated by the full adder, indicating a direct relationship where the full adder plays a crucial role in producing this sequence.
#
# In summary, the carry-out sequence is essential in binary arithmetic and is specifically generated by the full adder, showcasing the foundational role of these components in binary calculations.
#
# ===== COMMUNITY 7 =====
# The relationships outlined pertain to the paper titled "A Note on the Conversion of Nonnegative Integers to the Canonical Signed-digit Representation."
#
# 1. **Sections of the Paper**:
#    - The paper includes several key sections:
#      - **Abstract**: Summarizes the content of the paper.
#      - **Introduction**: Sets the context and introduces the concept of canonical signed-digit representation.
#      - **Literature Review**: Discusses existing methods, specifically highlighting Reitwiesner's method for signed-digit conversion.
#
# 2. **Key Concepts**:
#    - The **Canonical Signed-digit Representation** is a central theme mentioned in both the introduction and the literature review, indicating its significance in the context of the paper.
#
# 3. **Methodology**:
#    - The literature review section not only surveys existing methods but also specifically mentions Reitwiesner's method, showcasing its relevance to the topic of signed-digit conversion.
#
# In summary, the paper provides a comprehensive overview of the canonical signed-digit representation, contextualized through an abstract, introduction, and a detailed literature review that includes discussions on established methods like Reitwiesner's.
#
# ===== COMMUNITY 8 =====
# The relationships derived from the unknown paper highlight various algorithms, methods, and references that contribute to its discussions on computational techniques and performance evaluations. Below is a summary of the key entities and their relationships:
#
# 1. **Unknown Paper**:
#    - Discusses the **Ruiz-Granda algorithm** and its application in canonical signed-digit coding.
#    - Includes a **truth table** relevant to the **full adder** and mentions its role in generating the carry-out sequence.
#    - Contains sections detailing multiple algorithms, including:
#      - **Algorithm 2**: Describes conversion rules and references the truth table for deriving logic expressions.
#      - **Algorithm 4**: Details the NAF algorithm.
#      - **Algorithm 5**: Discusses the Binary to NAF algorithm.
#      - **Algorithm 6**: Details the Ruiz-Granda h and k sequences.
#      - **Algorithm 7**: Discusses the Ruiz-Granda algorithm.
#      - **Algorithm 11** and **Algorithm 12**: Each contains descriptions of specific algorithms.
#      - **Algorithm 13**: Describes the algorithm for solving carry-out recursion.
#    - Mentions the **Modified Reitwiesner's method** in relation to the algorithms presented.
#    - Cites significant works, including:
#      - **Reitwiesner's work** for arithmetic expressions.
#      - **Y. Tanaka** on efficient signed-digit-to-canonical-signed-digit recoding circuits.
#      - **G. A. Ruiz and M. Granda** on efficient canonic signed digit recoding.
#      - Documentation from **The Julia Project** and **Julia BenchmarkTools** for performance evaluation.
#    - Contains sections on various methods, including the **Garner method** and the **string substitution method**.
#    - Includes tables (Table 1, Table 2, Table 3) that present conversion rules and benchmark statistical summaries.
#    - Concludes with a section summarizing the findings of the paper.
#
# 2. **Additional Mentions**:
#    - The **finite-state machine** is referenced in the context of pattern substitution, indicating its relevance to the algorithms discussed.
#
# This summary encapsulates the critical elements of the relationships, emphasizing the paper's focus on algorithms, methods, and relevant citations that support its findings in computational techniques.
#
# ===== COMMUNITY 9 =====
# The relationships involving "Algorithm 13" and "Carry-out Sequence" highlight the algorithm's role in the context of a specific paper and its procedural content.
#
# 1. **Algorithm 13** is associated with an **Unknown Paper**, indicating that it is derived from the document's context. The paper includes a section that specifically describes the algorithm used for solving the carry-out recursion.
#
# 2. **Algorithm 13** also **contains** a detailed description of the procedure for generating the **Carry-out Sequence**. This relationship emphasizes the algorithm's functionality in producing this sequence.
#
# 3. Conversely, the **Carry-out Sequence** is noted to **contain** the same procedural description attributed to **Algorithm 13**, reinforcing the interconnectedness of these entities.
#
# In summary, "Algorithm 13" serves as a critical component in the unknown paper, detailing the methodology for the carry-out recursion and the generation of the carry-out sequence, which is reciprocally defined by the algorithm itself.
#
# ===== COMMUNITY 10 =====
# The relationships outlined involve two primary methods: the Garner Method and the String Substitution Method, both of which are discussed in an unspecified paper.
#
# 1. **Garner Method**:
#    - The paper includes a section dedicated to the Garner Method, which specifically contains Algorithm 1 for conversion purposes. This indicates that the Garner Method is a significant topic within the paper, providing practical algorithmic details.
#
# 2. **String Substitution Method**:
#    - Similarly, the paper features a section on the String Substitution Method, which also references Algorithm 1. This suggests that Algorithm 1 is relevant to both methods, highlighting its importance in the context of the paper.
#
# 3. **Algorithm 1**:
#    - Algorithm 1 serves as a common element between the two methods, being explicitly mentioned in both the Garner Method and the String Substitution Method sections. This reinforces the idea that Algorithm 1 plays a crucial role in the discussions of both methods.
#
# In summary, the relationships illustrate that both the Garner Method and the String Substitution Method are explored in the same paper, with Algorithm 1 serving as a key component linking the two methods together.
#
# ===== COMMUNITY 11 =====
# In the provided relationships, the key entities are "SECTION 5," "ALGORITHM 9," and "PAPER."
#
# 1. **SECTION 5 and ALGORITHM 9**: Section 5 contains a discussion specifically focused on Algorithm 9, indicating that this section elaborates on the details or implications of the algorithm.
#
# 2. **SECTION 5 and PAPER**: The paper includes Section 5, which is dedicated to discussing performance evaluation. This highlights the importance of Section 5 within the broader context of the paper.
#
# 3. **PAPER and SECTION 5**: This relationship reiterates that the paper encompasses Section 5, emphasizing its role in the overall structure of the document.
#
# In summary, Section 5 serves as a critical component of the paper, providing insights into Algorithm 9 and discussing performance evaluation, thereby linking theoretical aspects with practical implications.
#
# ===== COMMUNITY 12 =====
# The relationships among the algorithms can be summarized as follows:
#
# 1. **Algorithm 9 and Algorithm 5**: Algorithm 9 discusses the simplification of Algorithm 5, indicating a direct relationship where Algorithm 9 builds upon or refines the concepts presented in Algorithm 5.
#
# 2. **Algorithm 9 and Section 5**: Section 5 contains a discussion on Algorithm 9, suggesting that this section is dedicated to elaborating on the details and implications of Algorithm 9.
#
# 3. **Algorithm 5 and Algorithm 10**: Algorithm 5 is referenced in the context of Algorithm 10, highlighting that Algorithm 10 draws upon or relates to the principles established in Algorithm 5.
#
# Overall, the relationships illustrate a network of dependencies where Algorithm 9 simplifies Algorithm 5, and both Algorithm 5 and Algorithm 9 are interconnected with Algorithm 10, emphasizing their relevance in the broader context of algorithmic discussions.
#
# ===== COMMUNITY 13 =====
# The relationships outlined in the knowledge graph highlight the following key entities and their connections:
#
# 1. **REITWIESNER**:
#    - **Table 1**: The paper authored by REITWIESNER includes Table 1, which details rules for converting conventional binary numbers.
#    - **REITWIESNERMODIFIED**: This entity is related to REITWIESNER as it is derived from the original REITWIESNER algorithm.
#    - **GARNE**: Garner is acknowledged as the author of a work that discusses the canonical signed-digit code, which is associated with REITWIESNER.
#
# 2. **TABLE 1**:
#    - Reiterates its inclusion in the REITWIESNER paper, emphasizing its role in presenting conversion rules for binary numbers.
#
# 3. **GARNE**:
#    - Recognized for writing about the canonical signed-digit code, linking back to REITWIESNER.
#
# In summary, the relationships illustrate REITWIESNER's contributions to binary number conversion, its derivation of the REITWIESNERMODIFIED algorithm, and the acknowledgment of GARNE's work on related coding concepts.
#
# ===== COMMUNITY 14 =====
# The relationships among the entities in the provided knowledge graph can be summarized as follows:
#
# 1. **REITWIESNERMODIFIED**:
#    - Related to **REITWIESNER**: It is derived from the REITWIESNER algorithm.
#    - Related to **GARNERREVISITED**: This algorithm improves the performance of the REITWIESNER algorithm.
#    - Represented by **Algorithm 8**: The concept of REITWIESNERMODIFIED is encapsulated in this algorithm.
#    - Discussed in the **Conclusions** section: The conclusions highlight the significance and findings related to the REITWIESNERMODIFIED algorithm.
#
# 2. **GARNERREVISITED**:
#    - Related to **REITWIESNERMODIFIED**: It enhances the performance of the REITWIESNER algorithm.
#    - Represented by **Algorithm 10**: The concept of GARNERREVISITED is detailed in this algorithm.
#    - Mentioned in the **Conclusions** section: The conclusions provide insights into the GARNERREVISITED algorithm.
#
# 3. **Algorithms**:
#    - **Algorithm 8**: Contains the representation of REITWIESNERMODIFIED.
#    - **Algorithm 10**: Contains the representation of GARNERREVISITED and is derived from **Algorithm 9**. It also includes a section on performance evaluation and discussion.
#
# 4. **Conclusions**:
#    - Summarizes findings related to both **REITWIESNERMODIFIED** and **GARNERREVISITED**.
#    - Mentions additional algorithms, **STRING_0** and **STRING_1**, indicating a broader context of discussion within the conclusions.
#
# Overall, the relationships illustrate a network of algorithms where REITWIESNERMODIFIED and GARNERREVISITED are interconnected, with each algorithm contributing to the performance and understanding of the other, as well as being documented in the conclusions of the relevant papers.
#
# ===== COMMUNITY 15 =====
# The relationships outlined in the knowledge graph highlight various algorithms and their interconnections, particularly focusing on performance evaluations and discussions. Here’s a summary of the key entities and their relationships:
#
# 1. **STRING_0**:
#    - Discussed in the context of performance evaluation.
#    - Mentioned in the conclusions section of the related paper.
#
# 2. **Algorithm 9**:
#    - Derived from **Algorithm 3**.
#    - Related to **Algorithm 10**, which is also derived from it.
#    - Discussed in the performance evaluation section.
#
# 3. **Performance Evaluation and Discussion**:
#    - Contains sections discussing multiple algorithms, including **STRING_0**, **Algorithm 5**, **Algorithm 9**, and **Algorithm 10**.
#    - Associated with an unknown paper that discusses the performance evaluation of algorithms.
#
# 4. **Algorithm 3**:
#    - Related to both **Algorithm 5** and **Algorithm 9**.
#    - Serves as a foundational algorithm from which others are derived.
#
# 5. **Algorithm 5**:
#    - Related to **Algorithm 3**.
#    - Discussed in the context of performance evaluation.
#    - Contains a section detailing the **bin2naf algorithm**, which is also mentioned in the context of Algorithm 5.
#
# 6. **Algorithm 10**:
#    - Derived from **Algorithm 9** and discussed in the performance evaluation section.
#
# Overall, the relationships emphasize the interconnectedness of these algorithms, particularly how they derive from one another and their collective evaluation in performance contexts. The discussions surrounding these algorithms are crucial for understanding their applications and effectiveness in various scenarios.
#
# ===== COMMUNITY 16 =====
# The relationships highlight the connections between a literature review and specific methods discussed within it, particularly focusing on Reitwiesner's method for converting nonnegative integers to the canonical signed-digit representation.
#
# 1. **Literature Review**: This section of the paper provides an overview of existing methods related to the conversion of nonnegative integers, emphasizing its significance in the context of signed-digit representation.
#
# 2. **Reitwiesner's Method**: The literature review specifically mentions Reitwiesner's method, indicating its relevance and contribution to the field of signed-digit conversion.
#
# Overall, the literature review serves as a foundational element that contextualizes Reitwiesner's method, illustrating its importance in the broader discussion of integer conversion techniques.
#
# ===== COMMUNITY 17 =====
# The relationships outlined pertain to the paper titled "A Note on the Conversion of Nonnegative Integers to the Canonical Signed-digit Representation."
#
# 1. **Literature Review**: The paper includes a literature review section that discusses existing methods related to the conversion of nonnegative integers to the canonical signed-digit representation.
#
# 2. **Abstract**: The paper contains an abstract that summarizes its content, providing a concise overview of the main themes and findings.
#
# 3. **Introduction**: The introduction section of the paper sets the context for the research, outlining the significance and objectives of the study.
#
# Overall, the paper is structured with key sections that provide a comprehensive understanding of the topic, including a literature review, an abstract, and an introduction that collectively enhance the reader's grasp of the canonical signed-digit representation.
#
# ===== COMMUNITY 18 =====
# The relationships highlight the connections surrounding the concept of canonical signed-digit representation as discussed in a paper's introduction.
#
# 1. **Introduction** has a section that sets the context for the paper.
# 2. The **Introduction** mentions the concept of **Canonical Signed-digit Representation**, indicating its significance in the paper.
# 3. The **Canonical Signed-digit Representation** is reiterated in the **Introduction**, emphasizing its importance as a key topic of discussion.
#
# Overall, the introduction serves as a foundational element that not only contextualizes the paper but also emphasizes the relevance of the canonical signed-digit representation within the broader discussion.
#
# ===== COMMUNITY 19 =====
# The relationships derived from the "Unknown Paper" highlight various algorithms, methods, and references that are integral to its content. Below is a summary of the key entities and their relationships:
#
# 1. **Algorithms Discussed**:
#    - **Algorithm 2**: Describes conversion rules.
#    - **Algorithm 4**: Details the NAF (Non-Adjacent Form) algorithm.
#    - **Algorithm 5**: Covers the Binary to NAF algorithm.
#    - **Algorithm 6**: Details the Ruiz-Granda h and k sequences.
#    - **Algorithm 7**: Discusses the Ruiz-Granda algorithm.
#    - **Algorithm 11**: Contains a section describing Algorithm 11.
#    - **Algorithm 12**: Contains a section describing Algorithm 12.
#    - **Algorithm 13**: Describes the algorithm for solving the carry-out recursion.
#
# 2. **Methods and Concepts**:
#    - **Modified Reitwiesner's Method**: Discussed in relation to the algorithms presented.
#    - **Garner Method**: Contains a section on this method.
#    - **String Substitution Method**: Contains a section on this method.
#    - **Finite-State Machine**: Mentioned in the context of pattern substitution.
#    - **Full Adder**: Mentioned in relation to generating the carry-out sequence.
#
# 3. **Citations**:
#    - **Reitwiesner's Work**: Cited for its arithmetic expressions.
#    - **Y. Tanaka**: Cited for work on efficient signed-digit-to-canonical-signed-digit recoding circuits.
#    - **The Julia Project**: Cited for documentation.
#    - **Julia BenchmarkTools**: Cited as a reference for performance evaluation.
#    - **G. A. Ruiz and M. Granda**: Cited for work on efficient canonic signed digit recoding.
#
# 4. **Tables Included**:
#    - **Table 1**: Presents conversion rules.
#    - **Table 2**: Outlines conversion rules.
#    - **Table 3**: Displays benchmark statistical summaries.
#
# 5. **Conclusions**:
#    - The paper contains a conclusions section summarizing its findings.
#
# Overall, the "Unknown Paper" integrates various algorithms and methods, supported by significant citations, to provide a comprehensive discussion on efficient coding techniques and performance evaluations in computational contexts.
#
# ===== COMMUNITY 20 =====
# The relationships among the entities can be summarized as follows:
#
# 1. **Truth Table** and **Unknown Paper**: The Unknown Paper includes a truth table specifically for the full adder, indicating its relevance in the context of digital logic design.
#
# 2. **Truth Table** and **Algorithm 2**: Algorithm 2 references the truth table as a tool for deriving logic expressions, highlighting its importance in the algorithm's functionality.
#
# 3. **Algorithm 2** and **Unknown Paper**: The Unknown Paper describes Algorithm 2, which focuses on expressing conversion rules, suggesting that the algorithm plays a significant role in the paper's overall discussion.
#
# 4. **Algorithm 2** and **Truth Table**: Again, Algorithm 2 mentions the truth table, reinforcing its critical role in the derivation of logic expressions within the algorithm.
#
# Overall, the relationships emphasize the interconnectedness of the truth table, Algorithm 2, and the Unknown Paper, showcasing how these elements contribute to the understanding and application of logic expressions in digital systems.
#
# ===== COMMUNITY 21 =====
# In the provided relationships, we have the following entities and their connections:
#
# 1. **Algorithm 4** has a relationship with an **Unknown Paper**, indicating that the paper includes a section that details the NAF algorithm.
# 2. **Algorithm 4** also mentions the **NAF Algorithm**, highlighting that the section specifically refers to this algorithm.
# 3. Conversely, the **NAF Algorithm** mentions **Algorithm 4**, reinforcing that the section on Algorithm 4 discusses the NAF algorithm.
#
# In summary, the relationships illustrate that Algorithm 4 is a significant topic within an unknown paper, specifically detailing the NAF algorithm, which is also referenced back to Algorithm 4, creating a reciprocal acknowledgment between the two entities.
#
# ===== COMMUNITY 22 =====
# The relationships summarized from the knowledge graph are as follows:
#
# 1. **REITWIESNERMODIFIED and REITWIESNER**: The REITWIESNERMODIFIED algorithm is derived from the original REITWIESNER algorithm, indicating a foundational relationship where the modified version builds upon the original.
#
# 2. **REITWIESNERMODIFIED and GARNERREVISITED**: The GARNERREVISITED algorithm is related to REITWIESNERMODIFIED as it enhances the performance of the REITWIESNER algorithm, suggesting an improvement or optimization in the algorithmic approach.
#
# 3. **REITWIESNERMODIFIED and Algorithm 8**: The concept of REITWIESNERMODIFIED is represented by Algorithm 8, indicating that Algorithm 8 serves as a formal representation or implementation of the REITWIESNERMODIFIED algorithm.
#
# 4. **REITWIESNERMODIFIED and Conclusions**: The conclusions section of the related documentation discusses the REITWIESNERMODIFIED algorithm, highlighting its significance and the insights derived from its analysis.
#
# Overall, these relationships illustrate the evolution and contextual significance of the REITWIESNERMODIFIED algorithm in relation to its predecessors and related algorithms, as well as its formal representation and discussion in academic conclusions.
#
# ===== COMMUNITY 23 =====
# The relationships summarized from the knowledge graph highlight the connections and significance of the GARNERREVISITED concept and its associated algorithms:
#
# 1. **GARNERREVISITED and Algorithm 10**: The GARNERREVISITED concept is encapsulated by Algorithm 10, indicating that Algorithm 10 serves as a representation of this concept.
#
# 2. **GARNERREVISITED and REITWIESNERMODIFIED**: GARNERREVISITED is related to REITWIESNERMODIFIED, as it enhances the performance of the REITWIESNER algorithm, suggesting a developmental relationship where GARNERREVISITED builds upon or improves REITWIESNERMODIFIED.
#
# 3. **GARNERREVISITED and Conclusions**: The conclusions section of the relevant documentation explicitly mentions the GARNERREVISITED algorithm, underscoring its importance in the overall findings.
#
# 4. **Algorithm 10 and Algorithm 9**: Algorithm 10 is derived from Algorithm 9, indicating a lineage or evolution of algorithms where Algorithm 10 builds upon the foundations laid by Algorithm 9.
#
# 5. **Algorithm 10 and Performance Evaluation and Discussion**: The section dedicated to performance evaluation discusses Algorithm 10, highlighting its significance in assessing the effectiveness and efficiency of the algorithm.
#
# Overall, these relationships illustrate the foundational role of GARNERREVISITED and Algorithm 10 in the context of algorithmic development and performance evaluation, while also indicating the interconnections between various algorithms in this domain.
#
# ===== COMMUNITY 24 =====
# The relationships summarized from the knowledge graph highlight the connections between the "Conclusions" section of a paper and various algorithms, as well as the overall content of the paper.
#
# 1. **GARNERREVISITED**: The conclusions section mentions the GARNERREVISITED algorithm, indicating its relevance to the findings presented in the paper.
# 2. **REITWIESNERMODIFIED**: Similarly, the conclusions section discusses the REITWIESNERMODIFIED algorithm, suggesting its importance in the context of the research.
# 3. **Unknown Paper**: The paper includes a conclusions section that summarizes its findings, providing a general overview of the research outcomes.
# 4. **STRING_0**: The conclusions section also mentions the STRING_0 algorithm, further emphasizing the algorithms discussed in the paper.
# 5. **STRING_1**: The conclusions section mentions the STRING_1 algorithm, reinforcing its significance in the conclusions drawn from the research.
#
# Overall, the conclusions section serves as a critical component of the paper, summarizing key algorithms and their implications in the research findings.
#
# ===== COMMUNITY 25 =====
# The relationships among the algorithms can be summarized as follows:
#
# 1. **Algorithm 9 and Algorithm 3**: Algorithm 9 is derived from Algorithm 3, indicating a foundational relationship where Algorithm 3 serves as a precursor or source for Algorithm 9.
#
# 2. **Algorithm 9 and Algorithm 10**: Algorithm 10 is derived from Algorithm 9, suggesting a progression where Algorithm 9 serves as a basis for the development of Algorithm 10.
#
# 3. **Algorithm 9 and Performance Evaluation and Discussion**: The section titled "Performance Evaluation and Discussion" contains an analysis of Algorithm 9, focusing on its performance metrics and implications.
#
# 4. **Algorithm 3 and Algorithm 5**: Algorithm 5 is related to Algorithm 3, indicating a connection or relevance between these two algorithms, although the specific nature of this relationship is not detailed.
#
# Overall, the relationships illustrate a lineage of development from Algorithm 3 to Algorithm 9 and subsequently to Algorithm 10, while also highlighting the performance evaluation of Algorithm 9 and its connection to Algorithm 5.
#
# ===== COMMUNITY 26 =====
# The relationships outlined in the knowledge graph highlight the connections between a performance evaluation discussion and various algorithms, as well as the conclusions drawn from this evaluation.
#
# 1. **Performance Evaluation and Discussion** is a central entity that encompasses a paper discussing the performance evaluation of algorithms.
# 2. Within this discussion, specific algorithms are examined:
#    - **Algorithm 5** is analyzed in the context of performance evaluation.
#    - **Algorithm 9** is similarly discussed regarding its performance.
#    - **Algorithm 10** is also included in the performance evaluation analysis.
#    - **STRING_0** is another algorithm that is discussed in detail within the performance evaluation section.
# 3. The relationship between **STRING_0** and the **Performance Evaluation and Discussion** is reciprocal, indicating that the section not only discusses STRING_0 but also emphasizes its relevance in the overall evaluation.
# 4. Finally, the **Conclusions** section of the paper mentions **STRING_0**, suggesting that the findings related to this algorithm are significant enough to be highlighted in the concluding remarks.
#
# In summary, the relationships illustrate a comprehensive evaluation of multiple algorithms, with a particular emphasis on STRING_0, which is noted in both the performance evaluation and the conclusions of the paper.
#
# ===== COMMUNITY 27 =====
# The relationships involving "Algorithm 5" and "bin2naf Algorithm" highlight their interconnectedness and the context in which they are discussed.
#
# 1. **Algorithm 5** has a section in an **Unknown Paper** that details the Binary to NAF algorithm, indicating its significance in the broader context of the paper.
# 2. The **bin2naf Algorithm** is mentioned in the section about **Algorithm 5**, suggesting that it plays a role in the discussion or application of Algorithm 5.
# 3. **Algorithm 5** is related to **Algorithm 3**, indicating a potential link or comparison between these two algorithms.
# 4. The section titled **Performance Evaluation and Discussion** specifically discusses **Algorithm 5**, focusing on its performance metrics and implications.
#
# Overall, these relationships emphasize the importance of Algorithm 5 in the context of performance evaluation and its connection to both the bin2naf algorithm and Algorithm 3.

# %% [markdown]
# ### Debug: Verify Graph Structure
#
# Diagnostic cell to verify that the knowledge graph was built correctly:
# - Check total number of triplets extracted
# - Inspect sample triplets
# - View entity-community mappings
# - Confirm community summaries exist

# %%
# After building index, check if triplets exist:
triplets = index.property_graph_store.get_triplets()
print(f"Number of triplets: {len(triplets)}")
if triplets:
    print(f"Sample triplet: {triplets[0]}")

# Check community info
print(f"Entity info: {index.property_graph_store.entity_info}")
print(f"Community summaries: {index.property_graph_store.community_summary}")
# Out:
# Number of triplets: 136
# Sample triplet: [EntityNode(label='Paper', embedding=None, properties={'triplet_source_id': '2e6d7c42-1216-4bc3-80b1-ef92ac31f6e2', 'entity_description': 'The main paper discussing the signed-digit representation of non-negative integers.', 'types': ['Paper'], 'id': 'A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION'}, name='A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION'), Relation(label='has', source_id='A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION', target_id='LITERATURE REVIEW', properties={'triplet_source_id': '2e6d7c42-1216-4bc3-80b1-ef92ac31f6e2', 'relationship_description': 'The paper contains a section that reviews methods for canonical signed-digit conversion.'}), EntityNode(label='Section', embedding=None, properties={'triplet_source_id': '2e6d7c42-1216-4bc3-80b1-ef92ac31f6e2', 'entity_description': 'A section in the paper that reviews methods for canonical signed-digit conversion.', 'types': ['Section'], 'id': 'LITERATURE REVIEW'}, name='LITERATURE REVIEW')]
# Entity info: {'A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION': [0], 'LITERATURE REVIEW': [0], "REITWIESNER'S METHOD": [0], 'NAF ALGORITHM': [1], 'ALGORITHM 4': [1], 'CANONICAL SIGNED-DIGIT REPRESENTATION': [1], 'ALGORITHM 9': [2, 12], 'ALGORITHM 5': [2, 12], 'SECTION 5': [2, 11], 'ALGORITHM 10': [2, 12], 'PAPER': [2, 11], 'ALGORITHM 11': [3], 'TABLE 2': [3], 'ALGORITHM 12': [3], 'REITWIESNER': [4, 13], 'TABLE 1': [4, 13], 'REITWIESNERMODIFIED': [4, 14, 22], 'GARNE': [4, 13], 'GARNERREVISITED': [4, 14, 23], 'Algorithm 8': [4, 14, 22], 'Conclusions': [24, 4, 14], 'Algorithm 10': [4, 14, 23], 'Algorithm 9': [25, 4, 15], 'Performance Evaluation and Discussion': [26, 4, 15], 'STRING_0': [26, 4, 15], 'STRING_1': [24, 4, 14], 'Algorithm 5': [27, 4, 15], 'bin2naf Algorithm': [27, 4, 15], 'Algorithm 3': [25, 4, 15], 'Algorithm 11': [5], 'Algorithm 12': [5], 'Canonical Signed-Digit Representation': [5], 'BINARY ARITHMETIC': [6], 'CARRY-OUT SEQUENCE': [6], 'FULL ADDER': [6], 'A Note on the Conversion of Nonnegative Integers to the Canonical Signed-digit Representation': [17, 7], 'Literature Review': [16, 7], 'Abstract': [17, 7], 'Introduction': [18, 7], "Reitwiesner's Method": [16, 7], 'Canonical Signed-digit Representation': [18, 7], 'Unknown Paper (Derived from Document Context)': [8, 19], 'Algorithm 7': [8, 19], 'Truth Table': [8, 20], "Modified Reitwiesner's Method": [8, 19], "Reitwiesner's Work": [8, 19], 'Algorithm 6': [8, 19], 'Table 2': [8, 19], 'Y. Tanaka': [8, 19], 'The Julia Project': [8, 19], 'Julia BenchmarkTools': [8, 19], 'G. A. Ruiz and M. Granda': [8, 19], 'Table 3': [8, 19], 'Full Adder': [8, 19], 'Algorithm 2': [8, 20], 'Algorithm 4': [8, 21], 'Table 1': [8, 19], 'Finite-State Machine': [8, 19], 'Ruiz-Granda Algorithm': [8, 19], 'NAF Algorithm': [8, 21], 'Algorithm 13': [9], 'Carry-out Sequence': [9], 'Garner Method': [10], 'String Substitution Method': [10], 'Algorithm 1': [10]}
# Community summaries: {0: "The relationships outlined in the knowledge graph highlight the connections between various components of a paper focused on the conversion of nonnegative integers to the canonical signed-digit representation. \n\n1. **A NOTE ON THE CONVERSION OF NONNEGATIVE INTEGERS TO THE CANONICAL SIGNED-DIGIT REPRESENTATION** has a **LITERATURE REVIEW** that discusses methods for canonical signed-digit conversion, indicating that this section is crucial for understanding the existing techniques in the field.\n\n2. The **LITERATURE REVIEW** also references **REITWIESNER'S METHOD**, emphasizing its significance in the context of signed-digit conversion. This suggests that Reitwiesner's method is a notable approach within the broader discussion of conversion methods.\n\nOverall, the summary underscores the importance of the literature review in providing a comprehensive overview of canonical signed-digit conversion methods, with a specific mention of Reitwiesner's method as a key reference point in the discussion.", 1: "The relationships among the entities can be summarized as follows:\n\n1. **NAF ALGORITHM** and **ALGORITHM 4**: The NAF algorithm paper includes a section that describes Algorithm 4, indicating a direct reference and connection between the two.\n\n2. **ALGORITHM 4** and **CANONICAL SIGNED-DIGIT REPRESENTATION**: Algorithm 4 mentions the canonical signed-digit representation as part of its description, highlighting its relevance in the context of the algorithm's functionality.\n\nOverall, the NAF algorithm is closely linked to Algorithm 4, which in turn incorporates the canonical signed-digit representation, showcasing the interrelated nature of these concepts in the field of algorithms.", 2: 'The relationships among the entities can be summarized as follows:\n\n1. **Algorithm 9 and Algorithm 5**: Algorithm 9 discusses the simplification of Algorithm 5, indicating a direct relationship where Algorithm 9 builds upon or refines Algorithm 5.\n\n2. **Algorithm 9 and Section 5**: Section 5 contains a discussion on Algorithm 9, suggesting that this section is dedicated to elaborating on the concepts presented in Algorithm 9.\n\n3. **Algorithm 5 and Algorithm 10**: Algorithm 5 is referenced in the context of Algorithm 10, showing that Algorithm 10 relies on or relates to the principles established in Algorithm 5.\n\n4. **Section 5 and the Paper**: The paper includes Section 5, which discusses performance evaluation, highlighting the significance of this section within the broader context of the paper.\n\nOverall, the relationships illustrate a network of dependencies where Algorithms 9 and 5 are closely linked, with Section 5 serving as a critical component of the paper that evaluates the performance of these algorithms. Algorithm 10 also connects back to Algorithm 5, reinforcing its foundational role in the discussion.', 3: 'The relationships among the entities can be summarized as follows:\n\n- **Algorithm 11** and **Table 2**: Algorithm 11 contains references to the rules for converting binary numbers as detailed in Table 2. This relationship is reciprocal, as Table 2 also contains references to Algorithm 11.\n\n- **Algorithm 12** and **Table 2**: Similarly, Algorithm 12 contains references to the rules for converting binary numbers as outlined in Table 2, which again is a reciprocal relationship, with Table 2 referencing Algorithm 12.\n\nIn summary, both Algorithm 11 and Algorithm 12 are linked to Table 2, which serves as a source for the rules regarding binary number conversion, highlighting the interdependence of these algorithms and the table.', 4: '### Summary of Relationships\n\n1. **REITWIESNER and Table 1**: The paper includes Table 1, which presents rules for converting conventional binary numbers.\n\n2. **REITWIESNER and REITWIESNERMODIFIED**: REITWIESNERMODIFIED is derived from the REITWIESNER algorithm, indicating a direct relationship of evolution or improvement.\n\n3. **REITWIESNER and GARNE* ...
